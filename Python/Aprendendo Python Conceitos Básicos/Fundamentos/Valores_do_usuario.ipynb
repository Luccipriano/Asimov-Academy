# %% [markdown]
# # Aula de Input/Valores do usuário

# %%
input()
print('Olá')
input()
# Out:
# Olá
# 'asdf'

# %% [markdown]
# Input pode ser guardado em variváveis e controlado no código como qualquer outro dado.

# %%
x = input()
print("O input foi: " + x)
# Out:
# O input foi: asf

# %%
x = input("Digite um número:")
print("O número digitado foi:", x + ". E o seu tipo é:", type(x))
# Out:
# O número digitado foi: 34. E o seu tipo é: <class 'str'>

# %%
x = input("Digite um número:")
y = int(x)
print("O número digitado foi:", x + ". A sua metade é:", y/2)
# Out:
# O número digitado foi: 24. A sua metade é: 12.0
